# %%
import pandas as pd

#Let's import some packages to create some charts in Python
  # matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('previous_application.csv')

# %%
# check top 5 recrds
df.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START            ...            NAME_SELLER_INDUSTRY  \
# 0                       15            ...                    Connectivity
# 1                       11            ...                             XNA
# 2                       11            ...                             XNA
# 3                        7            ...                             XNA
# 4                        9            ...                             XNA
#
#    CNT_PAYMENT  NAME_YIELD_GROUP       PRODUCT_COMBINATION  \
# 0         12.0            middle  POS mobile with interest
# 1         36.0        low_action          Cash X-Sell: low
# 2         12.0              high         Cash X-Sell: high
# 3         12.0            middle       Cash X-Sell: middle
# 4         24.0              high         Cash Street: high
#
#    DAYS_FIRST_DRAWING DAYS_FIRST_DUE DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  \
# 0            365243.0          -42.0                     300.0          -42.0
# 1            365243.0         -134.0                     916.0       365243.0
# 2            365243.0         -271.0                      59.0       365243.0
# 3            365243.0         -482.0                    -152.0         -182.0
# 4                 NaN            NaN                       NaN            NaN
#
#   DAYS_TERMINATION NFLAG_INSURED_ON_APPROVAL
# 0            -37.0                       0.0
# 1         365243.0                       1.0
# 2         365243.0                       1.0
# 3           -177.0                       1.0
# 4              NaN                       NaN
#
# [5 rows x 37 columns]

# %%
# check column information
df.columns.values
# Out:
# array(['SK_ID_PREV', 'SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'AMT_ANNUITY',
#        'AMT_APPLICATION', 'AMT_CREDIT', 'AMT_DOWN_PAYMENT',
#        'AMT_GOODS_PRICE', 'WEEKDAY_APPR_PROCESS_START',
#        'HOUR_APPR_PROCESS_START', 'FLAG_LAST_APPL_PER_CONTRACT',
#        'NFLAG_LAST_APPL_IN_DAY', 'RATE_DOWN_PAYMENT',
#        'RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED',
#        'NAME_CASH_LOAN_PURPOSE', 'NAME_CONTRACT_STATUS', 'DAYS_DECISION',
#        'NAME_PAYMENT_TYPE', 'CODE_REJECT_REASON', 'NAME_TYPE_SUITE',
#        'NAME_CLIENT_TYPE', 'NAME_GOODS_CATEGORY', 'NAME_PORTFOLIO',
#        'NAME_PRODUCT_TYPE', 'CHANNEL_TYPE', 'SELLERPLACE_AREA',
#        'NAME_SELLER_INDUSTRY', 'CNT_PAYMENT', 'NAME_YIELD_GROUP',
#        'PRODUCT_COMBINATION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
#        'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE', 'DAYS_TERMINATION',
#        'NFLAG_INSURED_ON_APPROVAL'], dtype=object)

# %%
# check missing data
df.isnull().any()
# Out:
# SK_ID_PREV                     False
# SK_ID_CURR                     False
# NAME_CONTRACT_TYPE             False
# AMT_ANNUITY                     True
# AMT_APPLICATION                False
# AMT_CREDIT                     False
# AMT_DOWN_PAYMENT                True
# AMT_GOODS_PRICE                 True
# WEEKDAY_APPR_PROCESS_START     False
# HOUR_APPR_PROCESS_START        False
# FLAG_LAST_APPL_PER_CONTRACT    False
# NFLAG_LAST_APPL_IN_DAY         False
# RATE_DOWN_PAYMENT               True
# RATE_INTEREST_PRIMARY           True
# RATE_INTEREST_PRIVILEGED        True
# NAME_CASH_LOAN_PURPOSE         False
# NAME_CONTRACT_STATUS           False
# DAYS_DECISION                  False
# NAME_PAYMENT_TYPE              False
# CODE_REJECT_REASON             False
# NAME_TYPE_SUITE                 True
# NAME_CLIENT_TYPE               False
# NAME_GOODS_CATEGORY            False
# NAME_PORTFOLIO                 False
# NAME_PRODUCT_TYPE              False
# CHANNEL_TYPE                   False
# SELLERPLACE_AREA               False
# NAME_SELLER_INDUSTRY           False
# CNT_PAYMENT                     True
# NAME_YIELD_GROUP               False
# PRODUCT_COMBINATION            False
# DAYS_FIRST_DRAWING              True
# DAYS_FIRST_DUE                  True
# DAYS_LAST_DUE_1ST_VERSION       True
# DAYS_LAST_DUE                   True
# DAYS_TERMINATION                True
# NFLAG_INSURED_ON_APPROVAL       True
# dtype: bool

# %%
# check missing data
df.isnull().count()
# Out:
# SK_ID_PREV                     4050
# SK_ID_CURR                     4050
# NAME_CONTRACT_TYPE             4050
# AMT_ANNUITY                    4050
# AMT_APPLICATION                4050
# AMT_CREDIT                     4050
# AMT_DOWN_PAYMENT               4050
# AMT_GOODS_PRICE                4050
# WEEKDAY_APPR_PROCESS_START     4050
# HOUR_APPR_PROCESS_START        4050
# FLAG_LAST_APPL_PER_CONTRACT    4050
# NFLAG_LAST_APPL_IN_DAY         4050
# RATE_DOWN_PAYMENT              4050
# RATE_INTEREST_PRIMARY          4050
# RATE_INTEREST_PRIVILEGED       4050
# NAME_CASH_LOAN_PURPOSE         4050
# NAME_CONTRACT_STATUS           4050
# DAYS_DECISION                  4050
# NAME_PAYMENT_TYPE              4050
# CODE_REJECT_REASON             4050
# NAME_TYPE_SUITE                4050
# NAME_CLIENT_TYPE               4050
# NAME_GOODS_CATEGORY            4050
# NAME_PORTFOLIO                 4050
# NAME_PRODUCT_TYPE              4050
# CHANNEL_TYPE                   4050
# SELLERPLACE_AREA               4050
# NAME_SELLER_INDUSTRY           4050
# CNT_PAYMENT                    4050
# NAME_YIELD_GROUP               4050
# PRODUCT_COMBINATION            4050
# DAYS_FIRST_DRAWING             4050
# DAYS_FIRST_DUE                 4050
# DAYS_LAST_DUE_1ST_VERSION      4050
# DAYS_LAST_DUE                  4050
# DAYS_TERMINATION               4050
# NFLAG_INSURED_ON_APPROVAL      4050
# dtype: int64

# %%
df.isnull().sum()
# Out:
# SK_ID_PREV                        0
# SK_ID_CURR                        0
# NAME_CONTRACT_TYPE                0
# AMT_ANNUITY                     775
# AMT_APPLICATION                   0
# AMT_CREDIT                        0
# AMT_DOWN_PAYMENT               1811
# AMT_GOODS_PRICE                 794
# WEEKDAY_APPR_PROCESS_START        0
# HOUR_APPR_PROCESS_START           0
# FLAG_LAST_APPL_PER_CONTRACT       0
# NFLAG_LAST_APPL_IN_DAY            0
# RATE_DOWN_PAYMENT              1811
# RATE_INTEREST_PRIMARY          4032
# RATE_INTEREST_PRIVILEGED       4032
# NAME_CASH_LOAN_PURPOSE            0
# NAME_CONTRACT_STATUS              0
# DAYS_DECISION                     0
# NAME_PAYMENT_TYPE                 0
# CODE_REJECT_REASON                0
# NAME_TYPE_SUITE                1937
# NAME_CLIENT_TYPE                  0
# NAME_GOODS_CATEGORY               0
# NAME_PORTFOLIO                    0
# NAME_PRODUCT_TYPE                 0
# CHANNEL_TYPE                      0
# SELLERPLACE_AREA                  0
# NAME_SELLER_INDUSTRY              0
# CNT_PAYMENT                     775
# NAME_YIELD_GROUP                  0
# PRODUCT_COMBINATION               0
# DAYS_FIRST_DRAWING             1463
# DAYS_FIRST_DUE                 1463
# DAYS_LAST_DUE_1ST_VERSION      1463
# DAYS_LAST_DUE                  1463
# DAYS_TERMINATION               1463
# NFLAG_INSURED_ON_APPROVAL      1463
# dtype: int64

# %%
# create a function to check missing data and generate report
def missing_data(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/len(data)*100).sort_values(ascending = False)
    return pd.concat([total,percent], axis=1,keys=['Total', 'Percent']) # When axis=1, a DataFrame is returned

# %%
missing_data(df)
# Out:
#                              Total    Percent
# RATE_INTEREST_PRIMARY         4032  99.555556
# RATE_INTEREST_PRIVILEGED      4032  99.555556
# NAME_TYPE_SUITE               1937  47.827160
# RATE_DOWN_PAYMENT             1811  44.716049
# AMT_DOWN_PAYMENT              1811  44.716049
# DAYS_TERMINATION              1463  36.123457
# NFLAG_INSURED_ON_APPROVAL     1463  36.123457
# DAYS_FIRST_DRAWING            1463  36.123457
# DAYS_FIRST_DUE                1463  36.123457
# DAYS_LAST_DUE_1ST_VERSION     1463  36.123457
# DAYS_LAST_DUE                 1463  36.123457
# AMT_GOODS_PRICE                794  19.604938
# CNT_PAYMENT                    775  19.135802
# AMT_ANNUITY                    775  19.135802
# NAME_CONTRACT_TYPE               0   0.000000
# AMT_APPLICATION                  0   0.000000
# SK_ID_CURR                       0   0.000000
# WEEKDAY_APPR_PROCESS_START       0   0.000000
# HOUR_APPR_PROCESS_START          0   0.000000
# FLAG_LAST_APPL_PER_CONTRACT      0   0.000000
# NFLAG_LAST_APPL_IN_DAY           0   0.000000
# AMT_CREDIT                       0   0.000000
# NAME_PAYMENT_TYPE                0   0.000000
# NAME_CASH_LOAN_PURPOSE           0   0.000000
# NAME_CONTRACT_STATUS             0   0.000000
# DAYS_DECISION                    0   0.000000
# CODE_REJECT_REASON               0   0.000000
# NAME_CLIENT_TYPE                 0   0.000000
# NAME_GOODS_CATEGORY              0   0.000000
# NAME_PORTFOLIO                   0   0.000000
# NAME_PRODUCT_TYPE                0   0.000000
# CHANNEL_TYPE                     0   0.000000
# SELLERPLACE_AREA                 0   0.000000
# NAME_SELLER_INDUSTRY             0   0.000000
# NAME_YIELD_GROUP                 0   0.000000
# PRODUCT_COMBINATION              0   0.000000
# SK_ID_PREV                       0   0.000000

# %%
# basic statistical analysis
check_list=['AMT_APPLICATION', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_DOWN_PAYMENT','AMT_GOODS_PRICE']
for i in check_list:
    print(df[i].describe())
# Out:
# count    4.050000e+03
# mean     1.505871e+05
# std      2.556333e+05
# min      0.000000e+00
# 25%      2.478262e+04
# 50%      6.767100e+04
# 75%      1.485000e+05
# max      2.700000e+06
# Name: AMT_APPLICATION, dtype: float64
# count    4.050000e+03
# mean     1.691863e+05
# std      2.813868e+05
# min      0.000000e+00
# 25%      2.871000e+04
# 50%      7.488000e+04
# 75%      1.716952e+05
# max      3.020760e+06
# Name: AMT_CREDIT, dtype: float64
# count      3275.000000
# mean      14052.498678
# std       12733.534895
# min           0.000000
# 25%        5949.585000
# 50%       10014.795000
# 75%       17430.457500
# max      131892.660000
# Name: AMT_ANNUITY, dtype: float64
# count      2239.000000
# mean       6111.609419
# std       15337.516766
# min           0.000000
# 25%           0.000000
# 50%        1615.500000
# 75%        7650.000000
# max      489600.000000
# Name: AMT_DOWN_PAYMENT, dtype: float64
# count    3.256000e+03
# mean     1.873090e+05
# std      2.727792e+05
# min      0.000000e+00
# 25%      4.651650e+04
# 50%      9.189722e+04
# 75%      1.845000e+05
# max      2.700000e+06
# Name: AMT_GOODS_PRICE, dtype: float64

# %%
# Count number of records for each value:
df['NAME_CONTRACT_STATUS'].value_counts()
# Out:
# Approved        2665
# Refused          713
# Canceled         596
# Unused offer      76
# Name: NAME_CONTRACT_STATUS, dtype: int64

# %%
# Plot distribution
df['TARGET'].plot.hist(title = 'Load payed or not');
plt.xlabel('payed or not');
# 0 for the loan was repaid on time,1 indicating the client had payment difficulties

# %%
# Plot distribution
df['AMT_CREDIT'].plot.hist(title = 'Credit Distribution',color = 'green')
plt.xlabel('credit');

# %%
df['NAME_CONTRACT_TYPE'].value_counts()
# Out:
# Consumer loans     2159
# Cash loans         1430
# Revolving loans     461
# Name: NAME_CONTRACT_TYPE, dtype: int64
